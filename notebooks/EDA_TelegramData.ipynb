# %%
#import libraries
import pandas as pd

# %%
#load data
df = pd.read_csv('../data/telegram_data.csv')
df.tail()
# Out:
#                channel                                       text  \
# 234  @Bethyyonlineshop      Pj set\nPreorder 15-20days\n@bethyy21
# 235  @Bethyyonlineshop  Sleep Robe\nPreorder 15-20days\n@bethyy21
# 236  @Bethyyonlineshop  Sleep Robe\nPreorder 15-20days\n@bethyy21
# 237  @Bethyyonlineshop  Sleep Robe\nPreorder 15-20days\n@bethyy21
# 238  @Bethyyonlineshop  Sleep Robe\nPreorder 15-20days\n@bethyy21
#
#                      timestamp  views      sender_id  \
# 234  2025-02-20T08:37:28+00:00    197 -1001490372346
# 235  2025-02-20T08:31:54+00:00    200 -1001490372346
# 236  2025-02-20T08:31:31+00:00    195 -1001490372346
# 237  2025-02-20T08:27:29+00:00    200 -1001490372346
# 238  2025-02-20T08:26:15+00:00    182 -1001490372346
#
#                                          image  \
# 234  ../data/images/Bethyyonlineshop_22898.jpg
# 235  ../data/images/Bethyyonlineshop_22895.jpg
# 236  ../data/images/Bethyyonlineshop_22892.jpg
# 237  ../data/images/Bethyyonlineshop_22889.jpg
# ...
